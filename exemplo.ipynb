# %%
from quantumnet.components import Network, Host
from quantumnet.objects import Logger

Logger.activate(Logger)

rede = Network()
h1 = Host('arthur')
h2 = Host('david')
h3 = Host("polyan")

h1.add_connection('polyan')
h3.add_connection('arthur')

# h2.add_connection('arthur')
# h3.add_connection('david')

rede.add_host(h1)
rede.add_host(h2)
rede.add_host(h3)

rede.draw()

rede._graph.edges
# Out:
# 2024-05-13 17:54:43,526: Host arthur adicionado aos hosts da rede.
# 2024-05-13 17:54:43,527: Nó arthur adicionado ao grafo da rede.
# 2024-05-13 17:54:43,527: Conexões do arthur adicionados ao grafo da rede.
# 2024-05-13 17:54:43,527: Host david adicionado aos hosts da rede.
# 2024-05-13 17:54:43,528: Nó david adicionado ao grafo da rede.
# 2024-05-13 17:54:43,528: Host polyan adicionado aos hosts da rede.
# EdgeView([('arthur', 'polyan')])

# %%
print(rede._graph.nodes)
print(rede._graph.edges)
# Out:
# ['arthur', 'polyan', 'david']
# [('arthur', 'polyan')]
