# %%
from quantumnet.components import Network, Host
from quantumnet.objects import Qubit

# %%
rede = Network()
rede.set_ready_topology("Grade", 2, 3)
rede.draw()

# %%
# Criação de pares EPR
alice = rede.get_host(0)
bob = rede.get_host(5)
# Adicionando qubits aos hosts
alice.add_qubit(Qubit(0, 1))
bob.add_qubit(Qubit(1, 1))
# Acessando a memória dos hosts
print(alice.memory)
print(bob.memory)
# Out:
# [<quantumnet.objects.qubit.Qubit object at 0x723a0b3b1f30>]
# [<quantumnet.objects.qubit.Qubit object at 0x723a3444a320>]

# %%
# Usando as funções da camada física
rede.physical.entangle(alice,bob)
