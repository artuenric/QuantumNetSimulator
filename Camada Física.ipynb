# %%
from quantumnet.components import Network, Host
from quantumnet.objects import Qubit, Logger
Logger.activate(Logger)

# %%
rede = Network()
rede.set_ready_topology("Grade", 2, 3)
rede.draw()

# %%
# Criação de pares EPR
alice = rede.get_host(0)
bob = rede.get_host(1)
# Adicionando qubits aos hosts
alice.add_qubit(Qubit(0, 1))
bob.add_qubit(Qubit(1, 1))
# Acessando a memória dos hosts
print(alice.memory)
print(bob.memory)
print("Canais: ", rede.edges)
# Out:
# 2024-05-27 17:44:15,172: Qubit 0 adicionado à memória do Host 0.
# 2024-05-27 17:44:15,173: Qubit 1 adicionado à memória do Host 1.
# [<quantumnet.objects.qubit.Qubit object at 0x0000027EF811AB70>]
# [<quantumnet.objects.qubit.Qubit object at 0x0000027EFF27C770>]
# Canais:  [(0, 3), (0, 1), (1, 4), (1, 2), (2, 5), (3, 4), (4, 5)]

# %%
# Usando as funções da camada física
rede.start_hosts_and_channels()
rede.physical.echp_on_demand(0, 1)
# Out:
# 2024-05-27 17:44:15,179: Qubit 0 adicionado à memória do Host 0.
# 2024-05-27 17:44:15,179: Qubit 0 criado com fidelidade inicial 1.0 e adicionado à memória do Host 0.
# 2024-05-27 17:44:15,180: Qubit 1 adicionado à memória do Host 0.
# 2024-05-27 17:44:15,180: Qubit 1 criado com fidelidade inicial 1.0 e adicionado à memória do Host 0.
# 2024-05-27 17:44:15,180: Qubit 2 adicionado à memória do Host 0.
# 2024-05-27 17:44:15,181: Qubit 2 criado com fidelidade inicial 1.0 e adicionado à memória do Host 0.
# 2024-05-27 17:44:15,181: Qubit 3 adicionado à memória do Host 0.
# 2024-05-27 17:44:15,181: Qubit 3 criado com fidelidade inicial 1.0 e adicionado à memória do Host 0.
# 2024-05-27 17:44:15,182: Qubit 4 adicionado à memória do Host 0.
# 2024-05-27 17:44:15,182: Qubit 4 criado com fidelidade inicial 1.0 e adicionado à memória do Host 0.
# 2024-05-27 17:44:15,183: Qubit 5 adicionado à memória do Host 0.
# 2024-05-27 17:44:15,183: Qubit 5 criado com fidelidade inicial 1.0 e adicionado à memória do Host 0.
# 2024-05-27 17:44:15,184: Qubit 6 adicionado à memória do Host 0.
# 2024-05-27 17:44:15,184: Qubit 6 criado com fidelidade inicial 1.0 e adicionado à memória do Host 0.
# 2024-05-27 17:44:15,185: Qubit 7 adicionado à memória do Host 0.
# 2024-05-27 17:44:15,185: Qubit 7 criado com fidelidade inicial 1.0 e adicionado à memória do Host 0.
# 2024-05-27 17:44:15,185: Qubit 8 adicionado à memória do Host 0.
# 2024-05-27 17:44:15,186: Qubit 8 criado com fidelidade inicial 1.0 e adicionado à memória do Host 0.
# 2024-05-27 17:44:15,186: Qubit 9 adicionado à memória do Host 0.
# 2024-05-27 17:44:15,186: Qubit 9 criado com fidelidade inicial 1.0 e adicionado à memória do Host 0.
# 2024-05-27 17:44:15,186: Qubit 10 adicionado à memória do Host 1.
# 2024-05-27 17:44:15,187: Qubit 10 criado com fidelidade inicial 1.0 e adicionado à memória do Host 1.
# 2024-05-27 17:44:15,187: Qubit 11 adicionado à memória do Host 1.
# 2024-05-27 17:44:15,187: Qubit 11 criado com fidelidade inicial 1.0 e adicionado à memória do Host 1.
# 2024-05-27 17:44:15,188: Qubit 12 adicionado à memória do Host 1.
# 2024-05-27 17:44:15,188: Qubit 12 criado com fidelidade inicial 1.0 e adicionado à memória do Host 1.
# 2024-05-27 17:44:15,188: Qubit 13 adicionado à memória do Host 1.
# 2024-05-27 17:44:15,189: Qubit 13 criado com fidelidade inicial 1.0 e adicionado à memória do Host 1.
# 2024-05-27 17:44:15,189: Qubit 14 adicionado à memória do Host 1.
# 2024-05-27 17:44:15,189: Qubit 14 criado com fidelidade inicial 1.0 e adicionado à memória do Host 1.
# 2024-05-27 17:44:15,191: Qubit 15 adicionado à memória do Host 1.
# 2024-05-27 17:44:15,191: Qubit 15 criado com fidelidade inicial 1.0 e adicionado à memória do Host 1.
# 2024-05-27 17:44:15,192: Qubit 16 adicionado à memória do Host 1.
# 2024-05-27 17:44:15,192: Qubit 16 criado com fidelidade inicial 1.0 e adicionado à memória do Host 1.
# 2024-05-27 17:44:15,192: Qubit 17 adicionado à memória do Host 1.
# 2024-05-27 17:44:15,193: Qubit 17 criado com fidelidade inicial 1.0 e adicionado à memória do Host 1.
# 2024-05-27 17:44:15,193: Qubit 18 adicionado à memória do Host 1.
# 2024-05-27 17:44:15,193: Qubit 18 criado com fidelidade inicial 1.0 e adicionado à memória do Host 1.
# 2024-05-27 17:44:15,195: Qubit 19 adicionado à memória do Host 1.
# 2024-05-27 17:44:15,195: Qubit 19 criado com fidelidade inicial 1.0 e adicionado à memória do Host 1.
# 2024-05-27 17:44:15,196: Qubit 20 adicionado à memória do Host 2.
# 2024-05-27 17:44:15,196: Qubit 20 criado com fidelidade inicial 1.0 e adicionado à memória do Host 2.
# 2024-05-27 17:44:15,196: Qubit 21 adicionado à memória do Host 2.
# 2024-05-27 17:44:15,197: Qubit 21 criado com fidelidade inicial 1.0 e adicionado à memória do Host 2.
# 2024-05-27 17:44:15,197: Qubit 22 adicionado à memória do Host 2.
# 2024-05-27 17:44:15,198: Qubit 22 criado com fidelidade inicial 1.0 e adicionado à memória do Host 2.
# 2024-05-27 17:44:15,199: Qubit 23 adicionado à memória do Host 2.
# 2024-05-27 17:44:15,199: Qubit 23 criado com fidelidade inicial 1.0 e adicionado à memória do Host 2.
# 2024-05-27 17:44:15,199: Qubit 24 adicionado à memória do Host 2.
# 2024-05-27 17:44:15,199: Qubit 24 criado com fidelidade inicial 1.0 e adicionado à memória do Host 2.
# 2024-05-27 17:44:15,200: Qubit 25 adicionado à memória do Host 2.
# 2024-05-27 17:44:15,200: Qubit 25 criado com fidelidade inicial 1.0 e adicionado à memória do Host 2.
# 2024-05-27 17:44:15,200: Qubit 26 adicionado à memória do Host 2.
# 2024-05-27 17:44:15,201: Qubit 26 criado com fidelidade inicial 1.0 e adicionado à memória do Host 2.
# 2024-05-27 17:44:15,201: Qubit 27 adicionado à memória do Host 2.
# 2024-05-27 17:44:15,202: Qubit 27 criado com fidelidade inicial 1.0 e adicionado à memória do Host 2.
# 2024-05-27 17:44:15,202: Qubit 28 adicionado à memória do Host 2.
# 2024-05-27 17:44:15,203: Qubit 28 criado com fidelidade inicial 1.0 e adicionado à memória do Host 2.
# 2024-05-27 17:44:15,203: Qubit 29 adicionado à memória do Host 2.
# 2024-05-27 17:44:15,203: Qubit 29 criado com fidelidade inicial 1.0 e adicionado à memória do Host 2.
# 2024-05-27 17:44:15,204: Qubit 30 adicionado à memória do Host 3.
# 2024-05-27 17:44:15,204: Qubit 30 criado com fidelidade inicial 1.0 e adicionado à memória do Host 3.
# 2024-05-27 17:44:15,204: Qubit 31 adicionado à memória do Host 3.
# 2024-05-27 17:44:15,205: Qubit 31 criado com fidelidade inicial 1.0 e adicionado à memória do Host 3.
# 2024-05-27 17:44:15,205: Qubit 32 adicionado à memória do Host 3.
# 2024-05-27 17:44:15,206: Qubit 32 criado com fidelidade inicial 1.0 e adicionado à memória do Host 3.
# 2024-05-27 17:44:15,206: Qubit 33 adicionado à memória do Host 3.
# 2024-05-27 17:44:15,206: Qubit 33 criado com fidelidade inicial 1.0 e adicionado à memória do Host 3.
# 2024-05-27 17:44:15,206: Qubit 34 adicionado à memória do Host 3.
# 2024-05-27 17:44:15,207: Qubit 34 criado com fidelidade inicial 1.0 e adicionado à memória do Host 3.
# 2024-05-27 17:44:15,208: Qubit 35 adicionado à memória do Host 3.
# 2024-05-27 17:44:15,208: Qubit 35 criado com fidelidade inicial 1.0 e adicionado à memória do Host 3.
# 2024-05-27 17:44:15,209: Qubit 36 adicionado à memória do Host 3.
# 2024-05-27 17:44:15,209: Qubit 36 criado com fidelidade inicial 1.0 e adicionado à memória do Host 3.
# 2024-05-27 17:44:15,209: Qubit 37 adicionado à memória do Host 3.
# 2024-05-27 17:44:15,209: Qubit 37 criado com fidelidade inicial 1.0 e adicionado à memória do Host 3.
# 2024-05-27 17:44:15,210: Qubit 38 adicionado à memória do Host 3.
# 2024-05-27 17:44:15,210: Qubit 38 criado com fidelidade inicial 1.0 e adicionado à memória do Host 3.
# 2024-05-27 17:44:15,210: Qubit 39 adicionado à memória do Host 3.
# 2024-05-27 17:44:15,211: Qubit 39 criado com fidelidade inicial 1.0 e adicionado à memória do Host 3.
# 2024-05-27 17:44:15,211: Qubit 40 adicionado à memória do Host 4.
# 2024-05-27 17:44:15,212: Qubit 40 criado com fidelidade inicial 1.0 e adicionado à memória do Host 4.
# 2024-05-27 17:44:15,212: Qubit 41 adicionado à memória do Host 4.
# 2024-05-27 17:44:15,212: Qubit 41 criado com fidelidade inicial 1.0 e adicionado à memória do Host 4.
# 2024-05-27 17:44:15,212: Qubit 42 adicionado à memória do Host 4.
# 2024-05-27 17:44:15,213: Qubit 42 criado com fidelidade inicial 1.0 e adicionado à memória do Host 4.
# 2024-05-27 17:44:15,213: Qubit 43 adicionado à memória do Host 4.
# 2024-05-27 17:44:15,214: Qubit 43 criado com fidelidade inicial 1.0 e adicionado à memória do Host 4.
# 2024-05-27 17:44:15,214: Qubit 44 adicionado à memória do Host 4.
# 2024-05-27 17:44:15,215: Qubit 44 criado com fidelidade inicial 1.0 e adicionado à memória do Host 4.
# 2024-05-27 17:44:15,215: Qubit 45 adicionado à memória do Host 4.
# 2024-05-27 17:44:15,216: Qubit 45 criado com fidelidade inicial 1.0 e adicionado à memória do Host 4.
# 2024-05-27 17:44:15,216: Qubit 46 adicionado à memória do Host 4.
# 2024-05-27 17:44:15,217: Qubit 46 criado com fidelidade inicial 1.0 e adicionado à memória do Host 4.
# 2024-05-27 17:44:15,217: Qubit 47 adicionado à memória do Host 4.
# 2024-05-27 17:44:15,217: Qubit 47 criado com fidelidade inicial 1.0 e adicionado à memória do Host 4.
# 2024-05-27 17:44:15,218: Qubit 48 adicionado à memória do Host 4.
# 2024-05-27 17:44:15,218: Qubit 48 criado com fidelidade inicial 1.0 e adicionado à memória do Host 4.
# 2024-05-27 17:44:15,218: Qubit 49 adicionado à memória do Host 4.
# 2024-05-27 17:44:15,219: Qubit 49 criado com fidelidade inicial 1.0 e adicionado à memória do Host 4.
# 2024-05-27 17:44:15,219: Qubit 50 adicionado à memória do Host 5.
# 2024-05-27 17:44:15,219: Qubit 50 criado com fidelidade inicial 1.0 e adicionado à memória do Host 5.
# 2024-05-27 17:44:15,220: Qubit 51 adicionado à memória do Host 5.
# 2024-05-27 17:44:15,220: Qubit 51 criado com fidelidade inicial 1.0 e adicionado à memória do Host 5.
# 2024-05-27 17:44:15,220: Qubit 52 adicionado à memória do Host 5.
# 2024-05-27 17:44:15,220: Qubit 52 criado com fidelidade inicial 1.0 e adicionado à memória do Host 5.
# 2024-05-27 17:44:15,221: Qubit 53 adicionado à memória do Host 5.
# 2024-05-27 17:44:15,221: Qubit 53 criado com fidelidade inicial 1.0 e adicionado à memória do Host 5.
# 2024-05-27 17:44:15,221: Qubit 54 adicionado à memória do Host 5.
# 2024-05-27 17:44:15,222: Qubit 54 criado com fidelidade inicial 1.0 e adicionado à memória do Host 5.
# 2024-05-27 17:44:15,222: Qubit 55 adicionado à memória do Host 5.
# 2024-05-27 17:44:15,222: Qubit 55 criado com fidelidade inicial 1.0 e adicionado à memória do Host 5.
# 2024-05-27 17:44:15,223: Qubit 56 adicionado à memória do Host 5.
# 2024-05-27 17:44:15,225: Qubit 56 criado com fidelidade inicial 1.0 e adicionado à memória do Host 5.
# 2024-05-27 17:44:15,225: Qubit 57 adicionado à memória do Host 5.
# 2024-05-27 17:44:15,226: Qubit 57 criado com fidelidade inicial 1.0 e adicionado à memória do Host 5.
# 2024-05-27 17:44:15,226: Qubit 58 adicionado à memória do Host 5.
# 2024-05-27 17:44:15,226: Qubit 58 criado com fidelidade inicial 1.0 e adicionado à memória do Host 5.
# 2024-05-27 17:44:15,227: Qubit 59 adicionado à memória do Host 5.
# 2024-05-27 17:44:15,227: Qubit 59 criado com fidelidade inicial 1.0 e adicionado à memória do Host 5.
# 2024-05-27 17:44:15,227: A fidelidade do qubit Qubit 9 with state None é 1.0
# 2024-05-27 17:44:15,228: A fidelidade do qubit Qubit 19 with state None é 1.0
# 2024-05-27 17:44:15,228: A fidelidade do qubit Qubit 9 with state None é 1.0
# 2024-05-27 17:44:15,228: A fidelidade do qubit Qubit 19 with state None é 1.0
# 2024-05-27 17:44:15,228: A probabilidade de sucesso do ECHP é 1.0
# [<quantumnet.objects.qubit.Qubit object at 0x0000027EF811AB70>, <quantumnet.objects.qubit.Qubit object at 0x0000027EFF2D28A0>, <quantumnet.objects.qubit.Qubit object at 0x0000027EF96BDE80>, <quantumnet.objects.qubit.Qubit object at 0x0000027EF96BC5C0>, <quantumnet.objects.qubit.Qubit object at 0x0000027EFF059010>, <quantumnet.objects.qubit.Qubit object at 0x0000027EF9EC41D0>, <quantumnet.objects.qubit.Qubit object at 0x0000027EFF21A660>, <quantumnet.objects.qubit.Qubit object at 0x0000027EFF11D8E0>, <quantumnet.objects.qubit.Qubit object at 0x0000027EFF11D790>, <quantumnet.objects.qubit.Qubit object at 0x0000027EFF2D1FD0>, <quantumnet.objects.qubit.Qubit object at 0x0000027EFF2D3680>]
# [<quantumnet.objects.qubit.Qubit object at 0x0000027EFF27C770>, <quantumnet.objects.qubit.Qubit object at 0x0000027EFF21A6F0>, <quantumnet.objects.qubit.Qubit object at 0x0000027EFF27EFC0>, <quantumnet.objects.qubit.Qubit object at 0x0000027EF96BC410>, <quantumnet.objects.qubit.Qubit object at 0x0000027EFF1FA270>, <quantumnet.objects.qubit.Qubit object at 0x0000027EFF2AC290>, <quantumnet.objects.qubit.Qubit object at 0x0000027EFF2AD250>, <quantumnet.objects.qubit.Qubit object at 0x0000027EFF2AF0E0>, <quantumnet.objects.qubit.Qubit object at 0x0000027EFF2D37D0>, <quantumnet.objects.qubit.Qubit object at 0x0000027EF9C11790>, <quantumnet.objects.qubit.Qubit object at 0x0000027EFF21A870>]
# True

# %%
rede.edges[0, 1]
# Out:
# {'prob_on_demand_epr_create': 1.0,
#  'prob_replay_epr_create': 1.0,
#  'eprs': [<quantumnet.objects.epr.Epr at 0x27eff2e33e0>]}
